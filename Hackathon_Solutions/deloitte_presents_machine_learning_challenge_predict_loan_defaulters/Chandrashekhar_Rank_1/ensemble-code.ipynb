# %%
import numpy as np
import pandas as pd

# %%
grade_boost=pd.read_csv('/kaggle/input/ensem-dell/gradefinl.csv')
lgbm=pd.read_csv('/kaggle/input/ensem-dell/lgbmfinl.csv')
cat_boost=pd.read_csv('/kaggle/input/ensem-dell/catfinl.csv')

# %%
lgbm=grade_boost*0.42+lgbm*0.38+cat_boost*0.2

# %%
lgbm.to_csv('/kaggle/working/weightcatlgbpred5.csv',index=False)
