# %% [markdown]
# ## Predict Accident Risk Score

# %% [markdown]
# #### Install Python Packages

# %%
# !pip install category_encoders
# !pip install xgboost
# !pip install lightgbm

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np
import category_encoders as enc
from datetime import datetime
from tqdm import tqdm_notebook

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
import re
import math
import gc

warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn import preprocessing
from sklearn import model_selection
from sklearn import metrics

# %%
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor

# %% [markdown]
# #### Utility Functions

# %%
def show_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

def join_df(left, right, left_on, right_on=None, suffix='_y'):
    if right_on is None: right_on = left_on
    return left.merge(right, how='left', left_on=left_on, right_on=right_on, suffixes=("",suffix))

def get_feature_importance(clf, dataframe, feature_list, top_n=10):
  res = pd.DataFrame({'Feature':dataframe[feature_list].columns, 'Importance': clf.feature_importances_})
  return res.sort_values('Importance', ascending=False).head(top_n)

def generate_date_features(df, fldname, drop=False, time=False):
  fld = df[fldname]
  fld_dtype = fld.dtype
  if isinstance(fld_dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
    fld_dtype = np.datetime64
    
  if not np.issubdtype(fld_dtype, np.datetime64):
    df[fldname] = fld = pd.to_datetime(fld, infer_datetime_format=True)
  targ_pre = re.sub("[Dd]ate$", '', fldname)
  attr = ['Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear', 
         'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
  
  if time: attr = attr + ['Hour', 'Minute', 'Second']

  for n in attr: df[targ_pre + '_' + n] = getattr(fld.dt, n.lower())
  df[targ_pre+"_Is_weekend"] = df[targ_pre+"_Dayofweek"].apply(lambda x:True if x==5 or x==6 else False)
  df[targ_pre+"_Elapsed"] = fld.astype(np.int64) // 10**9
  if drop: df.drop(fldname, axis=1, inplace=True)
  return df

def get_area_code(text: str):
  text_list = text.split(" ")
  if len(text_list) > 1:
    return text_list[0] + text_list[1][0]
  else:
    return text_list[0]

def reduce_memory_usage(df, verbose=True):
    numerics = ["int8", "int16", "int32", "int64", "float16", "float32", "float64"]
    start_mem = df.memory_usage().sum() / 1024 ** 2
    for col in tqdm_notebook(df.columns):
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == "int":
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024 ** 2
    if verbose:
        print(
            "Mem. usage decreased to {:.2f} Mb ({:.1f}% reduction)".format(
                end_mem, 100 * (start_mem - end_mem) / start_mem
            )
        )
    return df

# %%
def run_clf(clf, fit_params, train_data, test_data, features, TARGET_COL, folds = 5):
    
    oofs = np.zeros(len(train_data))
    test_predictions = np.zeros((len(test_data)))
    model_scores = []
    y = train_data[TARGET_COL]
    
    for fold in range(folds):
        
      print(f'\n------------- Fold {fold + 1} -------------')

      xtrain = train_data[train_data[FOLD_COL] != fold]
      xvalid = train_data[train_data[FOLD_COL] == fold]
      xtest = test_data.copy()

      ytrain = xtrain[TARGET_COL]
      yvalid = xvalid[TARGET_COL]

      val_idx = xvalid.index.values
            
      xtrain = xtrain.reset_index(drop=True)
      xvalid = xvalid.reset_index(drop=True)
      
      xtrain = xtrain[features]
      xvalid = xvalid[features]
      xtest  = xtest[features]

      ############# Fitting and Predicting ################

      _ = clf.fit(xtrain
                  , ytrain
                  , eval_set=[(xtrain, ytrain), (xvalid, yvalid)]
                  , **fit_params
                  )

      preds_val = clf.predict(xvalid)
      preds_test = clf.predict(xtest)

      fold_score = np.round(metrics.mean_squared_error(yvalid, preds_val, squared=False), 5)
      model_scores.append(fold_score)
      print(f'\nRMSE for validation set is {fold_score}\n')

      # print(preds_test[0:10])
      
      oofs[val_idx] = preds_val
      test_predictions += preds_test / folds

    print(f'\nCV RMSE score: {np.round(np.mean(model_scores), 5)}')
    
    oofs_score = np.round(metrics.mean_squared_error(y, oofs, squared=False), 5)
    print(f'\nOOF RMSE score: {oofs_score}')

    return test_predictions, model_scores, clf, oofs

# %% [markdown]
# #### Reading Data

# %%
DIRECTORY_PATH = '/content/data'
TRAIN_CSV = DIRECTORY_PATH + '/train.csv'
TEST_CSV = DIRECTORY_PATH + '/test.csv'
ROADS_CSV = DIRECTORY_PATH + '/roads_network.csv'
POPULATION_CSV = DIRECTORY_PATH + '/population.csv'
SUBMISSION_CSV = DIRECTORY_PATH + '/sample_submission.csv'

# %%
df_train = pd.read_csv(TRAIN_CSV)
df_test = pd.read_csv(TEST_CSV)

df_roads = pd.read_csv(ROADS_CSV)
df_population = pd.read_csv(POPULATION_CSV)

df_submission = pd.read_csv(SUBMISSION_CSV)

# %%
df_train.shape, df_test.shape, df_submission.shape, df_roads.shape, df_population.shape
# Out:
# ((478741, 27), (121259, 27), (49772, 2), (91566, 8), (8035, 10))

# %%
show_all(df_train.head())
# Out:
#    Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 0            1            34                   2                     1
# 1            2             5                   2                     1
# 2            3             1                   2                     1
# 3            4             1                   1                     1
# 4            5            46                   1                     1
#
#        Date  Day_of_Week   Time  Local_Authority_(District)  \
# 0  19/12/12            7  13:20                         344
# 1  02/11/12            4   7:53                         102
# 2  02/11/12            4  16:00                         531
# 3  06/05/12            1  16:50                           7
# 4  30/06/12            3  13:25                         519
#
#   Local_Authority_(Highway)  1st_Road_Class  1st_Road_Number  \
# 0                 E10000032               4              395
# 1                 E09000026               3               13
# 2                 E10000016               6                8
# 3                 E08000035               6               13
# 4                 E10000031               3               24
#
#             Road_Type  Speed_limit  2nd_Road_Class  2nd_Road_Number  \
# 0  Single carriageway           30              -1                0
# 1      One way street           30              -1                0
# 2          Roundabout           40               6                0
# 3  Single carriageway           30               6                0
# 4    Dual carriageway           30               6                0
#
#   Pedestrian_Crossing-Human_Control Pedestrian_Crossing-Physical_Facilities  \
# 0             None within 50 metres   No physical crossing within 50 meters
# 1             None within 50 metres   No physical crossing within 50 meters
# 2             None within 50 metres                          Zebra crossing
# 3             None within 50 metres   No physical crossing within 50 meters
# 4             None within 50 metres                          Zebra crossing
#
#                  Light_Conditions          Weather_Conditions  \
# 0  Daylight: Street light present     Fine without high winds
# 1  Daylight: Street light present  Raining without high winds
# 2  Daylight: Street light present     Fine without high winds
# 3  Daylight: Street light present     Fine without high winds
# 4  Daylight: Street light present     Fine without high winds
#
#   Road_Surface_Conditions Special_Conditions_at_Site Carriageway_Hazards  \
# 0                     Dry               Ol or diesel                None
# 1                     Dry                       None                None
# 2                     Dry                       None                None
# 3                     Dry                  Roadworks                None
# 4                     Dry                       None                None
#
#    Urban_or_Rural_Area Did_Police_Officer_Attend_Scene_of_Accident    state  \
# 0                    1                                         Yes  England
# 1                    1                                          No  England
# 2                    1                                          No  England
# 3                    1                                         Yes  England
# 4                    1                                          No  England
#
#    postcode         country
# 0   OX3 9UP  United Kingdom
# 1   S35 4EZ  United Kingdom
# 2  BN21 2XR  United Kingdom
# 3  TA20 3PT  United Kingdom
# 4  DN20 0QF  United Kingdom

# %%
show_all(df_test.head())
# Out:
#    Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 0           14            13                   2                     0
# 1           17            13                   2                     0
# 2           21            13                   2                     0
# 3           23            13                   2                     0
# 4           28            14                   2                     0
#
#        Date  Day_of_Week   Time  Local_Authority_(District)  \
# 0  06/10/13            6  13:28                         218
# 1  22/04/13            7   9:30                         157
# 2  27/09/13            3  19:10                         155
# 3  13/03/13            4   9:19                          26
# 4  13/06/13            1  14:59                           6
#
#   Local_Authority_(Highway)  1st_Road_Class  1st_Road_Number  \
# 0                 E10000032               4             6358
# 1                 E10000034               6               29
# 2                 E09000012               3             5376
# 3                 E10000016               4             1252
# 4                 E08000012               4             1202
#
#             Road_Type  Speed_limit  2nd_Road_Class  2nd_Road_Number  \
# 0  Single carriageway           60               6                0
# 1  Single carriageway           30              -1                0
# 2          Roundabout           40               3                0
# 3  Single carriageway           30              -1                0
# 4  Single carriageway           30               3                0
#
#   Pedestrian_Crossing-Human_Control Pedestrian_Crossing-Physical_Facilities  \
# 0             None within 50 metres   No physical crossing within 50 meters
# 1             None within 50 metres   No physical crossing within 50 meters
# 2             None within 50 metres   No physical crossing within 50 meters
# 3             None within 50 metres   No physical crossing within 50 meters
# 4             None within 50 metres   No physical crossing within 50 meters
#
#                  Light_Conditions          Weather_Conditions  \
# 0  Daylight: Street light present  Snowing without high winds
# 1  Daylight: Street light present     Fine without high winds
# 2  Daylight: Street light present     Fine without high winds
# 3  Daylight: Street light present     Fine without high winds
# 4  Daylight: Street light present     Fine without high winds
#
#   Road_Surface_Conditions Special_Conditions_at_Site Carriageway_Hazards  \
# 0                     Dry                       None                None
# 1                     Dry                       None                None
# 2                Wet/Damp                       None                None
# 3                     Dry                       None                None
# 4                     Dry                       None                None
#
#    Urban_or_Rural_Area Did_Police_Officer_Attend_Scene_of_Accident    state  \
# 0                    2                                         Yes  England
# 1                    1                                          No  England
# 2                    1                                         Yes  England
# 3                    1                                         Yes  England
# 4                    1                                         Yes  England
#
#    postcode         country
# 0   HX2 8WH  United Kingdom
# 1   RM8 1DD  United Kingdom
# 2  SE23 1NH  United Kingdom
# 3  HU10 7QS  United Kingdom
# 4  BD23 5JL  United Kingdom

# %%
df_submission.head()
# Out:
#    postcode  Accident_risk_index
# 0  AB10 1AU                    0
# 1  AB10 1PG                    0
# 2  AB10 1TT                    0
# 3  AB10 1YP                    0
# 4  AB10 6LQ                    0

# %%
df_population.head()
# Out:
#   postcode Rural Urban  Variable: All usual residents; measures: Value  \
# 0   AL1  1       Total                                            5453
# 1   AL1  2       Total                                            6523
# 2   AL1  3       Total                                            4179
# 3   AL1  4       Total                                            9799
# 4   AL1  5       Total                                           10226
#
#    Variable: Males; measures: Value  Variable: Females; measures: Value  \
# 0                              2715                                2738
# 1                              3183                                3340
# 2                              2121                                2058
# 3                              4845                                4954
# 4                              5129                                5097
#
#    Variable: Lives in a household; measures: Value  \
# 0                                             5408
# 1                                             6418
# 2                                             4100
# 3                                             9765
# 4                                            10211
#
#    Variable: Lives in a communal establishment; measures: Value  \
# 0                                                 45
# 1                                                105
# 2                                                 79
# 3                                                 34
# 4                                                 15
#
#    Variable: Schoolchild or full-time student aged 4 and over at their non term-time address; measures: Value  \
# 0                                                 75
# 1                                                 77
# 2                                                 46
# 3                                                285
# 4                                                133
#
#    Variable: Area (Hectares); measures: Value  \
# 0                                      225.63
# 1                                      286.59
# 2                                       97.12
# 3                                      244.75
# 4                                      200.93
#
#    Variable: Density (number of persons per hectare); measures: Value
# 0                                               24.2
# 1                                               22.8
# 2                                               43.0
# 3                                               40.0
# 4                                               50.9

# %%
## Cleaning Population data
df_population.columns = ['areacode', 'rural_urban', 'residents', 'males', 'females', 'household_pop', 
                         'communal_pop', 'children', 'area', 'pop_density']
df_population = df_population.drop('rural_urban', axis=1)
df_population['areacode'] = df_population['areacode'].apply(lambda x: x.replace(" ", ""))

# %%
df_population.head()
# Out:
#   areacode  residents  males  females  household_pop  communal_pop  children  \
# 0     AL11       5453   2715     2738           5408            45        75
# 1     AL12       6523   3183     3340           6418           105        77
# 2     AL13       4179   2121     2058           4100            79        46
# 3     AL14       9799   4845     4954           9765            34       285
# 4     AL15      10226   5129     5097          10211            15       133
#
#      area  pop_density
# 0  225.63         24.2
# 1  286.59         22.8
# 2   97.12         43.0
# 3  244.75         40.0
# 4  200.93         50.9

# %%
## Adding features -> population data
df_population['male_ratio'] = df_population['males']/df_population['residents']
df_population['female_ratio'] = df_population['females']/df_population['residents']
df_population['child_ratio'] = df_population['children']/df_population['residents']
df_population['household_pop_ratio'] = df_population['household_pop']/df_population['residents']
df_population['communal_pop_ratio'] = df_population['communal_pop']/df_population['residents']

df_population['male_density'] = df_population['males']/df_population['area']
df_population['female_density'] = df_population['females']/df_population['area']
df_population['child_density'] = df_population['children']/df_population['area']
df_population['household_pop_density'] = df_population['household_pop']/df_population['area']
df_population['communal_pop_density'] = df_population['communal_pop']/df_population['area']

df_population['sex_ratio'] = df_population['males']/df_population['females']

# %%
show_all(df_population.head())
# Out:
#   areacode  residents  males  females  household_pop  communal_pop  children  \
# 0     AL11       5453   2715     2738           5408            45        75
# 1     AL12       6523   3183     3340           6418           105        77
# 2     AL13       4179   2121     2058           4100            79        46
# 3     AL14       9799   4845     4954           9765            34       285
# 4     AL15      10226   5129     5097          10211            15       133
#
#      area  pop_density  male_ratio  female_ratio  child_ratio  \
# 0  225.63         24.2    0.497891      0.502109     0.013754
# 1  286.59         22.8    0.487966      0.512034     0.011804
# 2   97.12         43.0    0.507538      0.492462     0.011007
# 3  244.75         40.0    0.494438      0.505562     0.029085
# 4  200.93         50.9    0.501565      0.498435     0.013006
#
#    household_pop_ratio  communal_pop_ratio  male_density  female_density  \
# 0             0.991748            0.008252     12.032974       12.134911
# 1             0.983903            0.016097     11.106459       11.654280
# 2             0.981096            0.018904     21.838962       21.190280
# 3             0.996530            0.003470     19.795710       20.241062
# 4             0.998533            0.001467     25.526303       25.367043
#
#    child_density  household_pop_density  communal_pop_density  sex_ratio
# 0       0.332403              23.968444              0.199442   0.991600
# 1       0.268677              22.394361              0.366377   0.952994
# 2       0.473641              42.215815              0.813427   1.030612
# 3       1.164454              39.897855              0.138917   0.977998
# 4       0.661922              50.818693              0.074653   1.006278

# %%
ID_COL = 'Accident_ID'
TARGET_COL = 'Number_of_Casualties'
RANDOM_STATE = 19920803
FOLD_COL = 'Kfold'
N_TRAILS = 10
N_FOLDS = 10

# %%
## Combining train and test datasets
df_full = pd.concat([df_train, df_test], axis=0)
df_full['is_train'] = np.where(df_full['Number_of_Casualties']==0, 0, 1)
df_full['Time'] = df_full['Time'].fillna('16:00')
df_full.shape
# Out:
# (600000, 28)

# %%
df_full['areacode'] = df_full['postcode'].apply(lambda x: get_area_code(x))

# %%
df_full = join_df(df_full, df_population, left_on='areacode')
df_full.shape
# Out:
# (600000, 48)

# %%
show_all(df_full.head())
# Out:
#    Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 0            1            34                   2                     1
# 1            2             5                   2                     1
# 2            3             1                   2                     1
# 3            4             1                   1                     1
# 4            5            46                   1                     1
#
#        Date  Day_of_Week   Time  Local_Authority_(District)  \
# 0  19/12/12            7  13:20                         344
# 1  02/11/12            4   7:53                         102
# 2  02/11/12            4  16:00                         531
# 3  06/05/12            1  16:50                           7
# 4  30/06/12            3  13:25                         519
#
#   Local_Authority_(Highway)  1st_Road_Class  1st_Road_Number  \
# 0                 E10000032               4              395
# 1                 E09000026               3               13
# 2                 E10000016               6                8
# 3                 E08000035               6               13
# 4                 E10000031               3               24
#
#             Road_Type  Speed_limit  2nd_Road_Class  2nd_Road_Number  \
# 0  Single carriageway           30              -1                0
# 1      One way street           30              -1                0
# 2          Roundabout           40               6                0
# 3  Single carriageway           30               6                0
# 4    Dual carriageway           30               6                0
#
#   Pedestrian_Crossing-Human_Control Pedestrian_Crossing-Physical_Facilities  \
# 0             None within 50 metres   No physical crossing within 50 meters
# 1             None within 50 metres   No physical crossing within 50 meters
# 2             None within 50 metres                          Zebra crossing
# 3             None within 50 metres   No physical crossing within 50 meters
# 4             None within 50 metres                          Zebra crossing
#
#                  Light_Conditions          Weather_Conditions  \
# 0  Daylight: Street light present     Fine without high winds
# 1  Daylight: Street light present  Raining without high winds
# 2  Daylight: Street light present     Fine without high winds
# 3  Daylight: Street light present     Fine without high winds
# 4  Daylight: Street light present     Fine without high winds
#
#   Road_Surface_Conditions Special_Conditions_at_Site Carriageway_Hazards  \
# 0                     Dry               Ol or diesel                None
# 1                     Dry                       None                None
# 2                     Dry                       None                None
# 3                     Dry                  Roadworks                None
# 4                     Dry                       None                None
#
#    Urban_or_Rural_Area Did_Police_Officer_Attend_Scene_of_Accident    state  \
# 0                    1                                         Yes  England
# 1                    1                                          No  England
# 2                    1                                          No  England
# 3                    1                                         Yes  England
# 4                    1                                          No  England
#
#    postcode         country  is_train areacode  residents   males  females  \
# 0   OX3 9UP  United Kingdom         1     OX39     8929.0  4268.0   4661.0
# 1   S35 4EZ  United Kingdom         1     S354     6360.0  3038.0   3322.0
# 2  BN21 2XR  United Kingdom         1    BN212     9050.0  4301.0   4749.0
# 3  TA20 3PT  United Kingdom         1    TA203     2690.0  1326.0   1364.0
# 4  DN20 0QF  United Kingdom         1    DN200     6875.0  3338.0   3537.0
#
#    household_pop  communal_pop  children     area  pop_density  male_ratio  \
# 0         8855.0          74.0     142.0  2575.85          3.5    0.477993
# 1         6341.0          19.0      43.0   265.07         24.0    0.477673
# 2         8492.0         558.0     115.0   327.07         27.7    0.475249
# 3         2685.0           5.0      43.0  6483.99          0.4    0.492937
# 4         6754.0         121.0      82.0  8404.23          0.8    0.485527
#
#    female_ratio  child_ratio  household_pop_ratio  communal_pop_ratio  \
# 0      0.522007     0.015903             0.991712            0.008288
# 1      0.522327     0.006761             0.997013            0.002987
# 2      0.524751     0.012707             0.938343            0.061657
# 3      0.507063     0.015985             0.998141            0.001859
# 4      0.514473     0.011927             0.982400            0.017600
#
#    male_density  female_density  child_density  household_pop_density  \
# 0      1.656929        1.809500       0.055127               3.437700
# 1     11.461123       12.532539       0.162221              23.921983
# 2     13.150090       14.519828       0.351607              25.963861
# 3      0.204504        0.210364       0.006632               0.414097
# 4      0.397181        0.420859       0.009757               0.803643
#
#    communal_pop_density  sex_ratio
# 0              0.028728   0.915683
# 1              0.071679   0.914509
# 2              1.706057   0.905664
# 3              0.000771   0.972141
# 4              0.014398   0.943738

# %%
## Generating features from Timestamp
df_full['Accident_ts'] = df_full['Date']+' '+df_full['Time']
df_full['Accident_ts'] = pd.to_datetime(df_full['Accident_ts'], format='%d/%m/%y %H:%M')
df_full['First_Date'] = df_full.groupby(['postcode'])['Accident_ts'].transform('min')
df_full['Days_Since_First_Accident'] = (df_full['Accident_ts'] - df_full['First_Date']).dt.days

df_full = generate_date_features(df_full, fldname='Accident_ts', time=True)
df_full.shape
# Out:
# (600000, 68)

# %%
df_full['postcode'].nunique(), df_full['areacode'].nunique()
# Out:
# (99689, 9421)

# %%
show_all(df_full[df_full['postcode']=='OX3 9UP'])
# Out:
#         Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 0                 1            34                   2                     1
# 91385        114321             1                   1                     1
# 121414       151919            21                   2                     3
# 180653       226233            34                   2                     2
# 210141       263194            62                   2                     1
# 337835       423353            93                   4                     3
# 525113       229950            95                   2                     0
#
#             Date  Day_of_Week   Time  Local_Authority_(District)  \
# 0       19/12/12            7  13:20                         344
# 91385   26/04/12            4  13:30                         728
# 121414  17/02/12            1  14:40                         325
# 180653  14/01/12            6  19:20                         347
# 210141  22/09/12            4   8:42                         778
# 337835  26/05/12            3   8:53                         922
# 525113  20/06/13            5  17:25                         928
#
#        Local_Authority_(Highway)  1st_Road_Class  1st_Road_Number  \
# 0                      E10000032               4              395
# 91385                  S12000041               6                5
# 121414                 E06000029               4              353
# 180653                 E08000032               3              308
# 210141                 E10000017               6              335
# 337835                 W06000015               3              325
# 525113                 E06000039               3              485
#
#                  Road_Type  Speed_limit  2nd_Road_Class  2nd_Road_Number  \
# 0       Single carriageway           30              -1                0
# 91385   Single carriageway           30               6                0
# 121414    Dual carriageway           70              -1                0
# 180653  Single carriageway           60               6                0
# 210141  Single carriageway           30               6                0
# 337835  Single carriageway           70              -1                0
# 525113    Dual carriageway           30               6                0
#
#        Pedestrian_Crossing-Human_Control  \
# 0                  None within 50 metres
# 91385              None within 50 metres
# 121414             None within 50 metres
# 180653             None within 50 metres
# 210141             None within 50 metres
# 337835             None within 50 metres
# 525113             None within 50 metres
#
#        Pedestrian_Crossing-Physical_Facilities  \
# 0        No physical crossing within 50 meters
# 91385    No physical crossing within 50 meters
# 121414   No physical crossing within 50 meters
# 180653   No physical crossing within 50 meters
# 210141   No physical crossing within 50 meters
# 337835   No physical crossing within 50 meters
# 525113   No physical crossing within 50 meters
#
#                                Light_Conditions       Weather_Conditions  \
# 0                Daylight: Street light present  Fine without high winds
# 91385            Daylight: Street light present  Fine without high winds
# 121414  Darkness: Street lights present and lit  Fine without high winds
# 180653           Daylight: Street light present  Fine without high winds
# 210141           Daylight: Street light present  Fine without high winds
# 337835           Daylight: Street light present  Fine without high winds
# 525113  Darkness: Street lights present and lit  Raining with high winds
#
#        Road_Surface_Conditions Special_Conditions_at_Site Carriageway_Hazards  \
# 0                          Dry               Ol or diesel                None
# 91385                 Wet/Damp                       None                None
# 121414                     Dry                       None                None
# 180653                     Dry                       None                None
# 210141                     Dry                       None                None
# 337835                     Dry                       None                None
# 525113                     Dry                       None                None
#
#         Urban_or_Rural_Area Did_Police_Officer_Attend_Scene_of_Accident  \
# 0                         1                                         Yes
# 91385                     1                                         Yes
# 121414                    2                                         Yes
# 180653                    2                                         Yes
# 210141                    1                                         Yes
# 337835                    2                                         Yes
# 525113                    1                                          No
#
#                   state postcode         country  is_train areacode  \
# 0               England  OX3 9UP  United Kingdom         1     OX39
# 91385     Cymru / Wales  OX3 9UP  United Kingdom         1     OX39
# 121414          England  OX3 9UP  United Kingdom         1     OX39
# 180653          England  OX3 9UP  United Kingdom         1     OX39
# 210141    Cymru / Wales  OX3 9UP  United Kingdom         1     OX39
# 337835  Alba / Scotland  OX3 9UP  United Kingdom         1     OX39
# 525113  Alba / Scotland  OX3 9UP  United Kingdom         0     OX39
#
#         residents   males  females  household_pop  communal_pop  children  \
# 0          8929.0  4268.0   4661.0         8855.0          74.0     142.0
# 91385      8929.0  4268.0   4661.0         8855.0          74.0     142.0
# 121414     8929.0  4268.0   4661.0         8855.0          74.0     142.0
# 180653     8929.0  4268.0   4661.0         8855.0          74.0     142.0
# 210141     8929.0  4268.0   4661.0         8855.0          74.0     142.0
# 337835     8929.0  4268.0   4661.0         8855.0          74.0     142.0
# 525113     8929.0  4268.0   4661.0         8855.0          74.0     142.0
#
#            area  pop_density  male_ratio  female_ratio  child_ratio  \
# 0       2575.85          3.5    0.477993      0.522007     0.015903
# 91385   2575.85          3.5    0.477993      0.522007     0.015903
# 121414  2575.85          3.5    0.477993      0.522007     0.015903
# 180653  2575.85          3.5    0.477993      0.522007     0.015903
# 210141  2575.85          3.5    0.477993      0.522007     0.015903
# 337835  2575.85          3.5    0.477993      0.522007     0.015903
# 525113  2575.85          3.5    0.477993      0.522007     0.015903
#
#         household_pop_ratio  communal_pop_ratio  male_density  female_density  \
# 0                  0.991712            0.008288      1.656929          1.8095
# 91385              0.991712            0.008288      1.656929          1.8095
# 121414             0.991712            0.008288      1.656929          1.8095
# 180653             0.991712            0.008288      1.656929          1.8095
# 210141             0.991712            0.008288      1.656929          1.8095
# 337835             0.991712            0.008288      1.656929          1.8095
# 525113             0.991712            0.008288      1.656929          1.8095
#
#         child_density  household_pop_density  communal_pop_density  sex_ratio  \
# 0            0.055127                 3.4377              0.028728   0.915683
# 91385        0.055127                 3.4377              0.028728   0.915683
# 121414       0.055127                 3.4377              0.028728   0.915683
# 180653       0.055127                 3.4377              0.028728   0.915683
# 210141       0.055127                 3.4377              0.028728   0.915683
# 337835       0.055127                 3.4377              0.028728   0.915683
# 525113       0.055127                 3.4377              0.028728   0.915683
#
#                Accident_ts          First_Date  Days_Since_First_Accident  \
# 0      2012-12-19 13:20:00 2012-01-14 19:20:00                        339
# 91385  2012-04-26 13:30:00 2012-01-14 19:20:00                        102
# 121414 2012-02-17 14:40:00 2012-01-14 19:20:00                         33
# 180653 2012-01-14 19:20:00 2012-01-14 19:20:00                          0
# 210141 2012-09-22 08:42:00 2012-01-14 19:20:00                        251
# 337835 2012-05-26 08:53:00 2012-01-14 19:20:00                        132
# 525113 2013-06-20 17:25:00 2012-01-14 19:20:00                        522
#
#         Accident_ts_Year  Accident_ts_Month  Accident_ts_Week  \
# 0                   2012                 12                51
# 91385               2012                  4                17
# 121414              2012                  2                 7
# 180653              2012                  1                 2
# 210141              2012                  9                38
# 337835              2012                  5                21
# 525113              2013                  6                25
#
#         Accident_ts_Day  Accident_ts_Dayofweek  Accident_ts_Dayofyear  \
# 0                    19                      2                    354
# 91385                26                      3                    117
# 121414               17                      4                     48
# 180653               14                      5                     14
# 210141               22                      5                    266
# 337835               26                      5                    147
# 525113               20                      3                    171
#
#         Accident_ts_Is_month_end  Accident_ts_Is_month_start  \
# 0                          False                       False
# 91385                      False                       False
# 121414                     False                       False
# 180653                     False                       False
# 210141                     False                       False
# 337835                     False                       False
# 525113                     False                       False
#
#         Accident_ts_Is_quarter_end  Accident_ts_Is_quarter_start  \
# 0                            False                         False
# 91385                        False                         False
# 121414                       False                         False
# 180653                       False                         False
# 210141                       False                         False
# 337835                       False                         False
# 525113                       False                         False
#
#         Accident_ts_Is_year_end  Accident_ts_Is_year_start  Accident_ts_Hour  \
# 0                         False                      False                13
# 91385                     False                      False                13
# 121414                    False                      False                14
# 180653                    False                      False                19
# 210141                    False                      False                 8
# 337835                    False                      False                 8
# 525113                    False                      False                17
#
#         Accident_ts_Minute  Accident_ts_Second  Accident_ts_Is_weekend  \
# 0                       20                   0                   False
# 91385                   30                   0                   False
# 121414                  40                   0                   False
# 180653                  20                   0                    True
# 210141                  42                   0                    True
# 337835                  53                   0                    True
# 525113                  25                   0                   False
#
#         Accident_ts_Elapsed
# 0                1355923200
# 91385            1335447000
# 121414           1329489600
# 180653           1326568800
# 210141           1348303320
# 337835           1338022380
# 525113           1371749100

# %%
## Filling NA values for categorical columns by mode
df_full['Road_Surface_Conditions'] = df_full['Road_Surface_Conditions'].fillna(df_full['Road_Surface_Conditions'].mode()[0])
df_full['Special_Conditions_at_Site'] = df_full['Special_Conditions_at_Site'].fillna(df_full['Special_Conditions_at_Site'].mode()[0])

# %%
## Checking NA values in dataframe
show_all(df_full.isna().sum())
# Out:
# Accident_ID                                        0
# Police_Force                                       0
# Number_of_Vehicles                                 0
# Number_of_Casualties                               0
# Date                                               0
# Day_of_Week                                        0
# Time                                               0
# Local_Authority_(District)                         0
# Local_Authority_(Highway)                          0
# 1st_Road_Class                                     0
# 1st_Road_Number                                    0
# Road_Type                                          0
# Speed_limit                                        0
# 2nd_Road_Class                                     0
# 2nd_Road_Number                                    0
# Pedestrian_Crossing-Human_Control                  0
# Pedestrian_Crossing-Physical_Facilities            0
# Light_Conditions                                   0
# Weather_Conditions                                 0
# Road_Surface_Conditions                            0
# Special_Conditions_at_Site                         0
# Carriageway_Hazards                                0
# Urban_or_Rural_Area                                0
# Did_Police_Officer_Attend_Scene_of_Accident        0
# state                                              0
# postcode                                           0
# country                                            0
# is_train                                           0
# areacode                                           0
# residents                                      43614
# males                                          43614
# females                                        43614
# household_pop                                  43614
# communal_pop                                   43614
# children                                       43614
# area                                           43614
# pop_density                                    43614
# male_ratio                                     43614
# female_ratio                                   43614
# child_ratio                                    43614
# household_pop_ratio                            43614
# communal_pop_ratio                             43614
# male_density                                   43614
# female_density                                 43614
# child_density                                  43614
# household_pop_density                          43614
# communal_pop_density                           43614
# sex_ratio                                      43614
# Accident_ts                                        0
# First_Date                                         0
# Days_Since_First_Accident                          0
# Accident_ts_Year                                   0
# Accident_ts_Month                                  0
# Accident_ts_Week                                   0
# Accident_ts_Day                                    0
# Accident_ts_Dayofweek                              0
# Accident_ts_Dayofyear                              0
# Accident_ts_Is_month_end                           0
# Accident_ts_Is_month_start                         0
# Accident_ts_Is_quarter_end                         0
# Accident_ts_Is_quarter_start                       0
# Accident_ts_Is_year_end                            0
# Accident_ts_Is_year_start                          0
# Accident_ts_Hour                                   0
# Accident_ts_Minute                                 0
# Accident_ts_Second                                 0
# Accident_ts_Is_weekend                             0
# Accident_ts_Elapsed                                0
# dtype: int64

# %%
def time_of_day(hour):
    if hour >= 5 and hour < 10:
        return "1"
    elif hour >= 10 and hour < 15:
        return "2"
    elif hour >= 15 and hour < 19:
        return "3"
    elif hour >= 19 and hour < 23:
        return "4"
    else:
        return "5"

# %%
df_full['day_group'] = df_full['Accident_ts_Hour'].apply(lambda x: time_of_day(x))

# %%
na_cols = ['residents', 'males', 'females', 'household_pop',
            'communal_pop', 'children', 'area', 'pop_density', 'male_ratio',
            'female_ratio', 'child_ratio', 'household_pop_ratio',
            'communal_pop_ratio', 'male_density', 'female_density', 'child_density',
            'household_pop_density', 'communal_pop_density', 'sex_ratio'
           ]

# %%
## filling NA values by median
df_full[na_cols] = df_full[na_cols].fillna(df_full[na_cols].median())

# %%
df_full.columns
# Out:
# Index(['Accident_ID', 'Police_Force', 'Number_of_Vehicles',
#        'Number_of_Casualties', 'Date', 'Day_of_Week', 'Time',
#        'Local_Authority_(District)', 'Local_Authority_(Highway)',
#        '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit',
#        '2nd_Road_Class', '2nd_Road_Number',
#        'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'state', 'postcode', 'country', 'is_train', 'areacode', 'residents',
#        'males', 'females', 'household_pop', 'communal_pop', 'children', 'area',
#        'pop_density', 'male_ratio', 'female_ratio', 'child_ratio',
#        'household_pop_ratio', 'communal_pop_ratio', 'male_density',
#        'female_density', 'child_density', 'household_pop_density',
#        'communal_pop_density', 'sex_ratio', 'Accident_ts', 'First_Date',
#        'Days_Since_First_Accident', 'Accident_ts_Year', 'Accident_ts_Month',
#        'Accident_ts_Week', 'Accident_ts_Day', 'Accident_ts_Dayofweek',
#        'Accident_ts_Dayofyear', 'Accident_ts_Is_month_end',
#        'Accident_ts_Is_month_start', 'Accident_ts_Is_quarter_end',
#        'Accident_ts_Is_quarter_start', 'Accident_ts_Is_year_end',
#        'Accident_ts_Is_year_start', 'Accident_ts_Hour', 'Accident_ts_Minute',
#        'Accident_ts_Second', 'Accident_ts_Is_weekend', 'Accident_ts_Elapsed',
#        'day_group'],
#       dtype='object')

# %%
unwanted_cols = [ID_COL, 
                 TARGET_COL, 
                 FOLD_COL, 
                 'is_train', 
                 '2nd_Road_Number',
                 'country',
                 'Accident_ts_Second',
                 'Accident_ts_Year'
                 ]

date_cols = ['Date', 
             'Time', 
             'Accident_ts', 
             'First_Date',
             ]

num_cols = [
 'Police_Force',
 'Number_of_Vehicles',
 '1st_Road_Number',
 'Speed_limit',
 'Days_Since_First_Accident',
 ]

object_cols = [
 'Day_of_Week',
 'Local_Authority_(District)',
 'Local_Authority_(Highway)',
 '1st_Road_Class',
 'Road_Type',
 '2nd_Road_Class',
 'Pedestrian_Crossing-Human_Control',
 'Pedestrian_Crossing-Physical_Facilities',
 'Light_Conditions',
 'Weather_Conditions',
 'Road_Surface_Conditions',
 'Special_Conditions_at_Site',
 'Carriageway_Hazards',
 'Urban_or_Rural_Area',
 'Did_Police_Officer_Attend_Scene_of_Accident',
 'state',
 'postcode',
 'day_group',
 'areacode'
 ]

len(num_cols), len(object_cols)
# Out:
# (5, 19)

# %%
## Adding aggregate feats
for ocol in tqdm_notebook([
                          'Day_of_Week',
                          'Local_Authority_(District)',
                          'Local_Authority_(Highway)',
                          '1st_Road_Class',
                          'Road_Type',
                          'postcode',
                          'day_group',
                          ]):
  print(ocol)
  for ncol in num_cols:
    df_full[f"{ocol}_{ncol}_min"] = df_full.groupby([ocol])[ncol].transform('min')
    df_full[f"{ocol}_{ncol}_max"] = df_full.groupby([ocol])[ncol].transform('max')
    df_full[f"{ocol}_{ncol}_avg"] = df_full.groupby([ocol])[ncol].transform('mean')
    df_full[f"{ocol}_{ncol}_median"] = df_full.groupby([ocol])[ncol].transform('median')
    df_full[f"{ocol}_{ncol}_sum"] = df_full.groupby([ocol])[ncol].transform('sum')
    df_full[f"{ocol}_{ncol}_diff"] = df_full[ncol] - df_full[f"{ocol}_{ncol}_avg"]
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# Day_of_Week
# Local_Authority_(District)
# Local_Authority_(Highway)
# 1st_Road_Class
# Road_Type
# postcode
# day_group

# %%
show_all(df_full.shape)
# Out:
# (600000, 279)

# %%
df_full['accidents_postcode_count'] = df_full.groupby(['postcode'])['Accident_ID'].transform('count')

df_full['days_postcode_unique'] = df_full.groupby(['postcode'])['Date'].transform('nunique')

for col in tqdm_notebook(object_cols):
  df_full[f'{col}_unq'] = df_full.groupby([col])['postcode'].transform('nunique')
  df_full[f'{col}_cnt'] = df_full.groupby([col])['postcode'].transform('count')
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]

# %%
## Splitting into train and test datasets
train_df = df_full[df_full['is_train']==1]
test_df = df_full[df_full['is_train']==0]
train_df.shape, test_df.shape
# Out:
# ((478741, 319), (121259, 319))

# %%
## Adding Kfolds to train data
kf = model_selection.KFold(n_splits=N_FOLDS, shuffle=True, random_state=RANDOM_STATE)
for fold, (train_idx, valid_idx) in enumerate(kf.split(X=train_df)):
    train_df.loc[valid_idx, FOLD_COL] = fold

# %%
train_df[FOLD_COL].value_counts()
# Out:
# 0.0    47875
# 5.0    47874
# 2.0    47874
# 8.0    47874
# 1.0    47874
# 7.0    47874
# 3.0    47874
# 6.0    47874
# 4.0    47874
# 9.0    47874
# Name: Kfold, dtype: int64

# %% [markdown]
# #### Target encoding - Categorical columns

# %%
# %%time
# Target Encoding
X = train_df[object_cols]
y = train_df[TARGET_COL].values

enc_train = np.zeros(X.shape)
smoothing = 0.3

Folds = model_selection.KFold(n_splits=N_FOLDS, random_state=RANDOM_STATE, shuffle=True)

for train_idx, valid_idx in Folds.split(X):
    encoder = enc.TargetEncoder(cols=object_cols, smoothing=smoothing)
  
    encoder.fit(X.loc[train_idx], y[train_idx])
    enc_train[valid_idx, :] = encoder.transform(X.iloc[valid_idx], y[valid_idx])

encoder.fit(X, y)
enc_test = encoder.transform(test_df[object_cols]).values

for idx, col in enumerate(object_cols):
    col = 'tE_' + col 
    train_df[col] = enc_train[:,idx]
    test_df[col] = enc_test[:, idx]
# Out:
# CPU times: user 1min 56s, sys: 2.11 s, total: 1min 58s
# Wall time: 1min 57s

# %%
## final feature set
features = [col for col in train_df.columns if col not in unwanted_cols + object_cols + date_cols]
len(features)
# Out:
# 308

# %%
train_df_low_mem = reduce_memory_usage(train_df)
test_df_low_mem = reduce_memory_usage(test_df)
# Out:
#   0%|          | 0/339 [00:00<?, ?it/s]
# Mem. usage decreased to 401.01 Mb (67.5% reduction)
#   0%|          | 0/338 [00:00<?, ?it/s]
# Mem. usage decreased to 97.25 Mb (68.4% reduction)

# %%
fit_params = {'verbose': 500, 'early_stopping_rounds': 200}

# %%
show_all(train_df_low_mem[features].head())
# Out:
#    Police_Force  Number_of_Vehicles  1st_Road_Number  Speed_limit  residents  \
# 0            34                   2              395           30     8928.0
# 1             5                   2               13           30     6360.0
# 2             1                   2                8           40     9048.0
# 3             1                   1               13           30     2690.0
# 4            46                   1               24           30     6876.0
#
#     males  females  household_pop  communal_pop  children    area  \
# 0  4268.0   4660.0         8856.0          74.0     142.0  2576.0
# 1  3038.0   3322.0         6340.0          19.0      43.0   265.0
# 2  4300.0   4748.0         8496.0         558.0     115.0   327.0
# 3  1326.0   1364.0         2684.0           5.0      43.0  6484.0
# 4  3338.0   3536.0         6752.0         121.0      82.0  8408.0
#
#    pop_density  male_ratio  female_ratio  child_ratio  household_pop_ratio  \
# 0     3.500000    0.478027      0.521973     0.015900             0.991699
# 1    24.000000    0.477783      0.522461     0.006760             0.997070
# 2    27.703125    0.475342      0.524902     0.012711             0.938477
# 3     0.399902    0.492920      0.506836     0.015991             0.998047
# 4     0.799805    0.485596      0.514648     0.011925             0.982422
#
#    communal_pop_ratio  male_density  female_density  child_density  \
# 0            0.008286      1.657227        1.809570       0.055115
# 1            0.002987     11.460938       12.531250       0.162231
# 2            0.061646     13.148438       14.523438       0.351562
# 3            0.001859      0.204468        0.210327       0.006630
# 4            0.017593      0.397217        0.420898       0.009758
#
#    household_pop_density  communal_pop_density  sex_ratio  \
# 0               3.437500              0.028732   0.915527
# 1              23.921875              0.071655   0.914551
# 2              25.968750              1.706055   0.905762
# 3               0.414062              0.000771   0.972168
# 4               0.803711              0.014397   0.943848
#
#    Days_Since_First_Accident  Accident_ts_Month  Accident_ts_Week  \
# 0                        339                 12                51
# 1                        246                 11                44
# 2                        265                 11                44
# 3                        101                  5                18
# 4                        141                  6                26
#
#    Accident_ts_Day  Accident_ts_Dayofweek  Accident_ts_Dayofyear  \
# 0               19                      2                    354
# 1                2                      4                    307
# 2                2                      4                    307
# 3                6                      6                    127
# 4               30                      5                    182
#
#    Accident_ts_Is_month_end  Accident_ts_Is_month_start  \
# 0                     False                       False
# 1                     False                       False
# 2                     False                       False
# 3                     False                       False
# 4                      True                       False
#
#    Accident_ts_Is_quarter_end  Accident_ts_Is_quarter_start  \
# 0                       False                         False
# 1                       False                         False
# 2                       False                         False
# 3                       False                         False
# 4                        True                         False
#
#    Accident_ts_Is_year_end  Accident_ts_Is_year_start  Accident_ts_Hour  \
# 0                    False                      False                13
# 1                    False                      False                 7
# 2                    False                      False                16
# 3                    False                      False                16
# 4                    False                      False                13
#
#    Accident_ts_Minute  Accident_ts_Is_weekend  Accident_ts_Elapsed  \
# 0                  20                   False           1355923200
# 1                  53                   False           1351842780
# 2                   0                   False           1351872000
# 3                  50                    True           1336323000
# 4                  25                    True           1341062700
#
#    Day_of_Week_Police_Force_min  Day_of_Week_Police_Force_max  \
# 0                             1                            98
# 1                             1                            98
# 2                             1                            98
# 3                             1                            98
# 4                             1                            98
#
#    Day_of_Week_Police_Force_avg  Day_of_Week_Police_Force_median  \
# 0                     24.578125                             15.0
# 1                     28.718750                             22.0
# 2                     28.718750                             22.0
# 3                     22.187500                             14.0
# 4                     28.546875                             21.0
#
#    Day_of_Week_Police_Force_sum  Day_of_Week_Police_Force_diff  \
# 0                       2354876                       9.421875
# 1                       1617099                     -23.718750
# 2                       1617099                     -27.718750
# 3                       1071647                     -21.187500
# 4                       3358520                      17.453125
#
#    Day_of_Week_Number_of_Vehicles_min  Day_of_Week_Number_of_Vehicles_max  \
# 0                                   1                                   4
# 1                                   1                                   4
# 2                                   1                                   4
# 3                                   1                                   4
# 4                                   1                                   4
#
#    Day_of_Week_Number_of_Vehicles_avg  Day_of_Week_Number_of_Vehicles_median  \
# 0                            1.704102                                    2.0
# 1                            1.784180                                    2.0
# 2                            1.784180                                    2.0
# 3                            1.708984                                    2.0
# 4                            1.767578                                    2.0
#
#    Day_of_Week_Number_of_Vehicles_sum  Day_of_Week_Number_of_Vehicles_diff  \
# 0                              163256                             0.296143
# 1                              100456                             0.216187
# 2                              100456                             0.216187
# 3                               82538                            -0.708984
# 4                              207911                            -0.767578
#
#    Day_of_Week_1st_Road_Number_min  Day_of_Week_1st_Road_Number_max  \
# 0                                0                             9832
# 1                                0                             9832
# 2                                0                             9832
# 3                                0                             9832
# 4                                0                             9832
#
#    Day_of_Week_1st_Road_Number_avg  Day_of_Week_1st_Road_Number_median  \
# 0                            939.5                               325.0
# 1                           1005.0                               354.0
# 2                           1005.0                               354.0
# 3                            870.0                                28.0
# 4                            930.5                               286.0
#
#    Day_of_Week_1st_Road_Number_sum  Day_of_Week_1st_Road_Number_diff  \
# 0                         90013777                            -544.5
# 1                         56586116                            -992.0
# 2                         56586116                            -997.0
# 3                         42016676                            -857.0
# 4                        109447494                            -906.5
#
#    Day_of_Week_Speed_limit_min  Day_of_Week_Speed_limit_max  \
# 0                           20                           70
# 1                           20                           70
# 2                           20                           70
# 3                           20                           70
# 4                           20                           70
#
#    Day_of_Week_Speed_limit_avg  Day_of_Week_Speed_limit_median  \
# 0                     37.09375                            30.0
# 1                     36.25000                            30.0
# 2                     36.25000                            30.0
# 3                     36.18750                            30.0
# 4                     36.03125                            30.0
#
#    Day_of_Week_Speed_limit_sum  Day_of_Week_Speed_limit_diff  \
# 0                      3555100                     -7.105469
# 1                      2041550                     -6.250000
# 2                      2041550                      3.748047
# 3                      1748320                     -6.203125
# 4                      4236690                     -6.019531
#
#    Day_of_Week_Days_Since_First_Accident_min  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#    Day_of_Week_Days_Since_First_Accident_max  \
# 0                                        723
# 1                                        720
# 2                                        720
# 3                                        722
# 4                                        722
#
#    Day_of_Week_Days_Since_First_Accident_avg  \
# 0                                    196.875
# 1                                    172.500
# 2                                    172.500
# 3                                    218.125
# 4                                    170.875
#
#    Day_of_Week_Days_Since_First_Accident_median  \
# 0                                         151.0
# 1                                         130.0
# 2                                         130.0
# 3                                         184.0
# 4                                         128.0
#
#    Day_of_Week_Days_Since_First_Accident_sum  \
# 0                                   18864825
# 1                                    9714457
# 2                                    9714457
# 3                                   10532312
# 4                                   20096702
#
#    Day_of_Week_Days_Since_First_Accident_diff  \
# 0                                  142.125000
# 1                                   73.500000
# 2                                   92.500000
# 3                                 -117.062500
# 4                                  -29.859375
#
#    Local_Authority_(District)_Police_Force_min  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
#
#    Local_Authority_(District)_Police_Force_max  \
# 0                                           95
# 1                                           96
# 2                                           63
# 3                                           63
# 4                                           96
#
#    Local_Authority_(District)_Police_Force_avg  \
# 0                                    29.968750
# 1                                     9.195312
# 2                                    41.906250
# 3                                     6.988281
# 4                                    40.218750
#
#    Local_Authority_(District)_Police_Force_median  \
# 0                                            33.0
# 1                                             6.0
# 2                                            44.0
# 3                                             1.0
# 4                                            43.0
#
#    Local_Authority_(District)_Police_Force_sum  \
# 0                                        22028
# 1                                        11967
# 2                                        51980
# 3                                        38356
# 4                                        59343
#
#    Local_Authority_(District)_Police_Force_diff  \
# 0                                      4.031250
# 1                                     -4.199219
# 2                                    -40.906250
# 3                                     -5.988281
# 4                                      5.792969
#
#    Local_Authority_(District)_Number_of_Vehicles_min  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Local_Authority_(District)_Number_of_Vehicles_max  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    Local_Authority_(District)_Number_of_Vehicles_avg  \
# 0                                           1.781250
# 1                                           1.908203
# 2                                           1.773438
# 3                                           1.859375
# 4                                           1.785156
#
#    Local_Authority_(District)_Number_of_Vehicles_median  \
# 0                                                2.0
# 1                                                2.0
# 2                                                2.0
# 3                                                2.0
# 4                                                2.0
#
#    Local_Authority_(District)_Number_of_Vehicles_sum  \
# 0                                               1309
# 1                                               2482
# 2                                               2199
# 3                                              10208
# 4                                               2635
#
#    Local_Authority_(District)_Number_of_Vehicles_diff  \
# 0                                           0.218994
# 1                                           0.092224
# 2                                           0.226562
# 3                                          -0.859375
# 4                                          -0.785156
#
#    Local_Authority_(District)_1st_Road_Number_min  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Local_Authority_(District)_1st_Road_Number_max  \
# 0                                            9395
# 1                                            7351
# 2                                            9214
# 3                                            9218
# 4                                            9084
#
#    Local_Authority_(District)_1st_Road_Number_avg  \
# 0                                         1073.00
# 1                                         1510.00
# 2                                         1180.00
# 3                                          463.25
# 4                                         1038.00
#
#    Local_Authority_(District)_1st_Road_Number_median  \
# 0                                              416.0
# 1                                               18.0
# 2                                              480.0
# 3                                               12.0
# 4                                              410.5
#
#    Local_Authority_(District)_1st_Road_Number_sum  \
# 0                                          788381
# 1                                         1963995
# 2                                         1463433
# 3                                         2542779
# 4                                         1532685
#
#    Local_Authority_(District)_1st_Road_Number_diff  \
# 0                                          -677.50
# 1                                         -1497.00
# 2                                         -1172.00
# 3                                          -450.25
# 4                                         -1014.50
#
#    Local_Authority_(District)_Speed_limit_min  \
# 0                                          20
# 1                                          20
# 2                                          20
# 3                                          20
# 4                                          20
#
#    Local_Authority_(District)_Speed_limit_max  \
# 0                                          70
# 1                                          70
# 2                                          70
# 3                                          70
# 4                                          70
#
#    Local_Authority_(District)_Speed_limit_avg  \
# 0                                    42.96875
# 1                                    33.12500
# 2                                    36.28125
# 3                                    30.15625
# 4                                    36.56250
#
#    Local_Authority_(District)_Speed_limit_median  \
# 0                                           30.0
# 1                                           30.0
# 2                                           30.0
# 3                                           30.0
# 4                                           30.0
#
#    Local_Authority_(District)_Speed_limit_sum  \
# 0                                       31580
# 1                                       43090
# 2                                       44990
# 3                                      165560
# 4                                       53980
#
#    Local_Authority_(District)_Speed_limit_diff  \
# 0                                   -12.968750
# 1                                    -3.121094
# 2                                     3.716797
# 3                                    -0.156616
# 4                                    -6.570312
#
#    Local_Authority_(District)_Days_Since_First_Accident_min  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Local_Authority_(District)_Days_Since_First_Accident_max  \
# 0                                                656
# 1                                                712
# 2                                                689
# 3                                                717
# 4                                                697
#
#    Local_Authority_(District)_Days_Since_First_Accident_avg  \
# 0                                            123.125
# 1                                            187.000
# 2                                            154.125
# 3                                            282.000
# 4                                            145.625
#
#    Local_Authority_(District)_Days_Since_First_Accident_median  \
# 0                                               86.0
# 1                                              132.0
# 2                                              127.0
# 3                                              268.5
# 4                                              118.5
#
#    Local_Authority_(District)_Days_Since_First_Accident_sum  \
# 0                                              90491
# 1                                             243361
# 2                                             191047
# 3                                            1547549
# 4                                             214976
#
#    Local_Authority_(District)_Days_Since_First_Accident_diff  \
# 0                                         215.875000
# 1                                          58.937500
# 2                                         110.937500
# 3                                        -180.875000
# 4                                          -4.648438
#
#    Local_Authority_(Highway)_Police_Force_min  \
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           1
#
#    Local_Authority_(Highway)_Police_Force_max  \
# 0                                          96
# 1                                          97
# 2                                          98
# 3                                          96
# 4                                          98
#
#    Local_Authority_(Highway)_Police_Force_avg  \
# 0                                   30.234375
# 1                                   12.476562
# 2                                   30.281250
# 3                                   29.437500
# 4                                   23.312500
#
#    Local_Authority_(Highway)_Police_Force_median  \
# 0                                           33.0
# 1                                            6.0
# 2                                           43.0
# 3                                           36.0
# 4                                           15.0
#
#    Local_Authority_(Highway)_Police_Force_sum  \
# 0                                      544583
# 1                                       33455
# 2                                     1028900
# 3                                      401457
# 4                                      203907
#
#    Local_Authority_(Highway)_Police_Force_diff  \
# 0                                     3.763672
# 1                                    -7.480469
# 2                                   -29.281250
# 3                                   -28.437500
# 4                                    22.687500
#
#    Local_Authority_(Highway)_Number_of_Vehicles_min  \
# 0                                                 1
# 1                                                 1
# 2                                                 1
# 3                                                 1
# 4                                                 1
#
#    Local_Authority_(Highway)_Number_of_Vehicles_max  \
# 0                                                 4
# 1                                                 4
# 2                                                 4
# 3                                                 4
# 4                                                 4
#
#    Local_Authority_(Highway)_Number_of_Vehicles_avg  \
# 0                                          1.678711
# 1                                          1.866211
# 2                                          1.831055
# 3                                          1.708008
# 4                                          1.682617
#
#    Local_Authority_(Highway)_Number_of_Vehicles_median  \
# 0                                                2.0
# 1                                                2.0
# 2                                                2.0
# 3                                                2.0
# 4                                                2.0
#
#    Local_Authority_(Highway)_Number_of_Vehicles_sum  \
# 0                                             30229
# 1                                              5003
# 2                                             62209
# 3                                             23299
# 4                                             14717
#
#    Local_Authority_(Highway)_Number_of_Vehicles_diff  \
# 0                                           0.321533
# 1                                           0.133911
# 2                                           0.169189
# 3                                          -0.708496
# 4                                          -0.682129
#
#    Local_Authority_(Highway)_1st_Road_Number_min  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    Local_Authority_(Highway)_1st_Road_Number_max  \
# 0                                           9803
# 1                                           9326
# 2                                           9693
# 3                                           9687
# 4                                           9666
#
#    Local_Authority_(Highway)_1st_Road_Number_avg  \
# 0                                         1075.0
# 1                                         1462.0
# 2                                          978.0
# 3                                          960.0
# 4                                          933.0
#
#    Local_Authority_(Highway)_1st_Road_Number_median  \
# 0                                             447.0
# 1                                             374.0
# 2                                              22.0
# 3                                             370.0
# 4                                              25.0
#
#    Local_Authority_(Highway)_1st_Road_Number_sum  \
# 0                                       19353340
# 1                                        3920370
# 2                                       33230716
# 3                                       13094539
# 4                                        8164825
#
#    Local_Authority_(Highway)_1st_Road_Number_diff  \
# 0                                          -679.5
# 1                                         -1449.0
# 2                                          -970.0
# 3                                          -947.0
# 4                                          -909.0
#
#    Local_Authority_(Highway)_Speed_limit_min  \
# 0                                         20
# 1                                         20
# 2                                         20
# 3                                         20
# 4                                         20
#
#    Local_Authority_(Highway)_Speed_limit_max  \
# 0                                         70
# 1                                         70
# 2                                         70
# 3                                         70
# 4                                         70
#
#    Local_Authority_(Highway)_Speed_limit_avg  \
# 0                                   44.12500
# 1                                   33.56250
# 2                                   34.50000
# 3                                   39.18750
# 4                                   35.34375
#
#    Local_Authority_(Highway)_Speed_limit_median  \
# 0                                          40.0
# 1                                          30.0
# 2                                          30.0
# 3                                          30.0
# 4                                          30.0
#
#    Local_Authority_(Highway)_Speed_limit_sum  \
# 0                                     794900
# 1                                      89950
# 2                                    1172570
# 3                                     534630
# 4                                     309350
#
#    Local_Authority_(Highway)_Speed_limit_diff  \
# 0                                  -14.132812
# 1                                   -3.550781
# 2                                    5.492188
# 3                                   -9.195312
# 4                                   -5.359375
#
#    Local_Authority_(Highway)_Days_Since_First_Accident_min  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Local_Authority_(Highway)_Days_Since_First_Accident_max  \
# 0                                                717
# 1                                                710
# 2                                                722
# 3                                                721
# 4                                                717
#
#    Local_Authority_(Highway)_Days_Since_First_Accident_avg  \
# 0                                            129.125
# 1                                            219.750
# 2                                            147.250
# 3                                            158.750
# 4                                            204.875
#
#    Local_Authority_(Highway)_Days_Since_First_Accident_median  \
# 0                                               93.0
# 1                                              173.0
# 2                                              120.0
# 3                                              119.0
# 4                                              164.0
#
#    Local_Authority_(Highway)_Days_Since_First_Accident_sum  \
# 0                                            2324922
# 1                                             589021
# 2                                            5003804
# 3                                            2165176
# 4                                            1792478
#
#    Local_Authority_(Highway)_Days_Since_First_Accident_diff  \
# 0                                         209.875000
# 1                                          26.296875
# 2                                         117.750000
# 3                                         -57.750000
# 4                                         -63.875000
#
#    1st_Road_Class_Police_Force_min  1st_Road_Class_Police_Force_max  \
# 0                                1                               98
# 1                                1                               98
# 2                                1                               98
# 3                                1                               98
# 4                                1                               98
#
#    1st_Road_Class_Police_Force_avg  1st_Road_Class_Police_Force_median  \
# 0                        25.828125                                21.0
# 1                        32.343750                                22.0
# 2                        24.406250                                14.0
# 3                        24.406250                                14.0
# 4                        32.343750                                22.0
#
#    1st_Road_Class_Police_Force_sum  1st_Road_Class_Police_Force_diff  \
# 0                          2566902                          8.164062
# 1                          6479986                        -27.359375
# 2                          5104189                        -23.406250
# 3                          5104189                        -23.406250
# 4                          6479986                         13.648438
#
#    1st_Road_Class_Number_of_Vehicles_min  \
# 0                                      1
# 1                                      1
# 2                                      1
# 3                                      1
# 4                                      1
#
#    1st_Road_Class_Number_of_Vehicles_max  \
# 0                                      4
# 1                                      4
# 2                                      4
# 3                                      4
# 4                                      4
#
#    1st_Road_Class_Number_of_Vehicles_avg  \
# 0                               1.833984
# 1                               1.775391
# 2                               1.703125
# 3                               1.703125
# 4                               1.775391
#
#    1st_Road_Class_Number_of_Vehicles_median  \
# 0                                       2.0
# 1                                       2.0
# 2                                       2.0
# 3                                       2.0
# 4                                       2.0
#
#    1st_Road_Class_Number_of_Vehicles_sum  \
# 0                                 182199
# 1                                 355583
# 2                                 356072
# 3                                 356072
# 4                                 355583
#
#    1st_Road_Class_Number_of_Vehicles_diff  1st_Road_Class_1st_Road_Number_min  \
# 0                                0.166260                                   0
# 1                                0.224609                                   0
# 2                                0.296875                                   0
# 3                               -0.703125                                   0
# 4                               -0.775391                                   0
#
#    1st_Road_Class_1st_Road_Number_max  1st_Road_Class_1st_Road_Number_avg  \
# 0                                9832                              1538.0
# 1                                9832                              1174.0
# 2                                9572                               457.5
# 3                                9572                               457.5
# 4                                9832                              1174.0
#
#    1st_Road_Class_1st_Road_Number_median  1st_Road_Class_1st_Road_Number_sum  \
# 0                                  502.0                           152814152
# 1                                  451.0                           235051256
# 2                                   10.0                            95653889
# 3                                   10.0                            95653889
# 4                                  451.0                           235051256
#
#    1st_Road_Class_1st_Road_Number_diff  1st_Road_Class_Speed_limit_min  \
# 0                              -1143.0                              20
# 1                              -1161.0                              20
# 2                               -449.5                              20
# 3                               -444.5                              20
# 4                              -1150.0                              20
#
#    1st_Road_Class_Speed_limit_max  1st_Road_Class_Speed_limit_avg  \
# 0                              70                       37.000000
# 1                              70                       39.687500
# 2                              70                       31.359375
# 3                              70                       31.359375
# 4                              70                       39.687500
#
#    1st_Road_Class_Speed_limit_median  1st_Road_Class_Speed_limit_sum  \
# 0                               30.0                         3675770
# 1                               30.0                         7949210
# 2                               30.0                         6556040
# 3                               30.0                         6556040
# 4                               30.0                         7949210
#
#    1st_Road_Class_Speed_limit_diff  \
# 0                        -6.996094
# 1                        -9.687500
# 2                         8.640625
# 3                        -1.358398
# 4                        -9.687500
#
#    1st_Road_Class_Days_Since_First_Accident_min  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    1st_Road_Class_Days_Since_First_Accident_max  \
# 0                                           723
# 1                                           724
# 2                                           727
# 3                                           727
# 4                                           724
#
#    1st_Road_Class_Days_Since_First_Accident_avg  \
# 0                                       200.500
# 1                                       159.000
# 2                                       195.375
# 3                                       195.375
# 4                                       159.000
#
#    1st_Road_Class_Days_Since_First_Accident_median  \
# 0                                            158.0
# 1                                            111.0
# 2                                            154.0
# 3                                            154.0
# 4                                            111.0
#
#    1st_Road_Class_Days_Since_First_Accident_sum  \
# 0                                      19924971
# 1                                      31837015
# 2                                      40858288
# 3                                      40858288
# 4                                      31837015
#
#    1st_Road_Class_Days_Since_First_Accident_diff  Road_Type_Police_Force_min  \
# 0                                      138.50000                           1
# 1                                       87.06250                           1
# 2                                       69.56250                           1
# 3                                      -94.43750                           1
# 4                                      -17.96875                           1
#
#    Road_Type_Police_Force_max  Road_Type_Police_Force_avg  \
# 0                          98                   27.000000
# 1                          98                   25.828125
# 2                          98                   22.296875
# 3                          98                   27.000000
# 4                          98                   36.812500
#
#    Road_Type_Police_Force_median  Road_Type_Police_Force_sum  \
# 0                           21.0                    12882090
# 1                            7.0                      696395
# 2                           13.0                      769775
# 3                           21.0                    12882090
# 4                           32.0                     2241158
#
#    Road_Type_Police_Force_diff  Road_Type_Number_of_Vehicles_min  \
# 0                     6.996094                                 1
# 1                   -20.828125                                 1
# 2                   -21.296875                                 1
# 3                   -26.000000                                 1
# 4                     9.179688                                 1
#
#    Road_Type_Number_of_Vehicles_max  Road_Type_Number_of_Vehicles_avg  \
# 0                                 4                          1.727539
# 1                                 4                          1.970703
# 2                                 4                          1.931641
# 3                                 4                          1.727539
# 4                                 4                          1.746094
#
#    Road_Type_Number_of_Vehicles_median  Road_Type_Number_of_Vehicles_sum  \
# 0                                  2.0                            824343
# 1                                  2.0                             53149
# 2                                  2.0                             66704
# 3                                  2.0                            824343
# 4                                  2.0                            106288
#
#    Road_Type_Number_of_Vehicles_diff  Road_Type_1st_Road_Number_min  \
# 0                           0.271973                              0
# 1                           0.029251                              0
# 2                           0.067932                              0
# 3                          -0.728027                              0
# 4                          -0.746094                              0
#
#    Road_Type_1st_Road_Number_max  Road_Type_1st_Road_Number_avg  \
# 0                           9832                          900.0
# 1                           9754                         1435.0
# 2                           9788                         1437.0
# 3                           9832                          900.0
# 4                           9687                          918.5
#
#    Road_Type_1st_Road_Number_median  Road_Type_1st_Road_Number_sum  \
# 0                             160.0                      429330416
# 1                             430.0                       38706272
# 2                             445.0                       49627859
# 3                             160.0                      429330416
# 4                             396.0                       55923420
#
#    Road_Type_1st_Road_Number_diff  Road_Type_Speed_limit_min  \
# 0                          -505.0                         20
# 1                         -1422.0                         20
# 2                         -1429.0                         20
# 3                          -887.0                         20
# 4                          -894.5                         20
#
#    Road_Type_Speed_limit_max  Road_Type_Speed_limit_avg  \
# 0                         70                   36.21875
# 1                         70                   33.53125
# 2                         70                   34.71875
# 3                         70                   36.21875
# 4                         70                   38.81250
#
#    Road_Type_Speed_limit_median  Road_Type_Speed_limit_sum  \
# 0                          30.0                   17280330
# 1                          30.0                     903890
# 2                          30.0                    1198390
# 3                          30.0                   17280330
# 4                          30.0                    2361770
#
#    Road_Type_Speed_limit_diff  Road_Type_Days_Since_First_Accident_min  \
# 0                   -6.222656                                        0
# 1                   -3.515625                                        0
# 2                    5.289062                                        0
# 3                   -6.222656                                        0
# 4                   -8.796875                                        0
#
#    Road_Type_Days_Since_First_Accident_max  \
# 0                                      727
# 1                                      712
# 2                                      722
# 3                                      727
# 4                                      724
#
#    Road_Type_Days_Since_First_Accident_avg  \
# 0                                  184.625
# 1                                  150.125
# 2                                  172.875
# 3                                  184.625
# 4                                  145.500
#
#    Road_Type_Days_Since_First_Accident_median  \
# 0                                       140.0
# 1                                       119.0
# 2                                       132.0
# 3                                       140.0
# 4                                        97.0
#
#    Road_Type_Days_Since_First_Accident_sum  \
# 0                                 88085100
# 1                                  4048893
# 2                                  5967572
# 3                                 88085100
# 4                                  8859304
#
#    Road_Type_Days_Since_First_Accident_diff  postcode_Police_Force_min  \
# 0                                154.375000                          1
# 1                                 95.875000                          1
# 2                                 92.125000                          1
# 3                                -83.625000                          1
# 4                                 -4.539062                          1
#
#    postcode_Police_Force_max  postcode_Police_Force_avg  \
# 0                         95                  48.562500
# 1                         52                  15.585938
# 2                         95                  31.718750
# 3                         52                  25.328125
# 4                         46                  20.078125
#
#    postcode_Police_Force_median  postcode_Police_Force_sum  \
# 0                          34.0                        340
# 1                          12.5                        187
# 2                          32.0                        444
# 3                          22.0                        304
# 4                          17.5                        241
#
#    postcode_Police_Force_diff  postcode_Number_of_Vehicles_min  \
# 0                  -14.570312                                1
# 1                  -10.585938                                1
# 2                  -30.718750                                1
# 3                  -24.328125                                1
# 4                   25.921875                                1
#
#    postcode_Number_of_Vehicles_max  postcode_Number_of_Vehicles_avg  \
# 0                                4                         2.142578
# 1                                4                         2.000000
# 2                                3                         1.857422
# 3                                2                         1.750000
# 4                                2                         1.583008
#
#    postcode_Number_of_Vehicles_median  postcode_Number_of_Vehicles_sum  \
# 0                                 2.0                               15
# 1                                 2.0                               24
# 2                                 2.0                               26
# 3                                 2.0                               21
# 4                                 2.0                               19
#
#    postcode_Number_of_Vehicles_diff  postcode_1st_Road_Number_min  \
# 0                         -0.142822                             5
# 1                          0.000000                             0
# 2                          0.142822                             0
# 3                         -0.750000                             3
# 4                         -0.583496                             6
#
#    postcode_1st_Road_Number_max  postcode_1st_Road_Number_avg  \
# 0                           485                        315.25
# 1                          6434                        763.50
# 2                          2228                        570.00
# 3                          5275                       1184.00
# 4                          5228                        665.50
#
#    postcode_1st_Road_Number_median  postcode_1st_Road_Number_sum  \
# ...
# 3                                -35.90625                           1
# 4                               -134.25000                           1
#
#    day_group_Police_Force_max  day_group_Police_Force_avg  \
# 0                          98                   27.734375
# 1                          98                   27.687500
# 2                          98                   28.281250
# 3                          98                   28.281250
# 4                          98                   27.734375
#
#    day_group_Police_Force_median  day_group_Police_Force_sum  \
# 0                           21.0                     5581957
# 1                           21.0                     2760582
# 2                           21.0                     5149469
# 3                           21.0                     5149469
# 4                           21.0                     5581957
#
#    day_group_Police_Force_diff  day_group_Number_of_Vehicles_min  \
# 0                     6.269531                                 1
# 1                   -22.687500                                 1
# 2                   -27.281250                                 1
# 3                   -27.281250                                 1
# 4                    18.265625                                 1
#
#    day_group_Number_of_Vehicles_max  day_group_Number_of_Vehicles_avg  \
# 0                                 4                          1.769531
# 1                                 4                          1.744141
# 2                                 4                          1.756836
# 3                                 4                          1.756836
# 4                                 4                          1.769531
#
#    day_group_Number_of_Vehicles_median  day_group_Number_of_Vehicles_sum  \
# 0                                  2.0                            356137
# 1                                  2.0                            173902
# 2                                  2.0                            320018
# 3                                  2.0                            320018
# 4                                  2.0                            356137
#
#    day_group_Number_of_Vehicles_diff  day_group_1st_Road_Number_min  \
# 0                           0.230835                              0
# 1                           0.255859                              0
# 2                           0.242798                              0
# 3                          -0.757324                              0
# 4                          -0.769043                              0
#
#    day_group_1st_Road_Number_max  day_group_1st_Road_Number_avg  \
# 0                           9832                          984.0
# 1                           9832                          956.5
# 2                           9832                          954.0
# 3                           9832                          954.0
# 4                           9832                          984.0
#
#    day_group_1st_Road_Number_median  day_group_1st_Road_Number_sum  \
# 0                             328.0                      198126563
# 1                             332.0                       95374034
# 2                             300.0                      173765221
# 3                             300.0                      173765221
# 4                             328.0                      198126563
#
#    day_group_1st_Road_Number_diff  day_group_Speed_limit_min  \
# 0                          -589.0                         20
# 1                          -943.5                         20
# 2                          -946.0                         20
# 3                          -941.0                         20
# 4                          -960.0                         20
#
#    day_group_Speed_limit_max  day_group_Speed_limit_avg  \
# 0                         70                   36.12500
# 1                         70                   36.53125
# 2                         70                   36.03125
# 3                         70                   36.03125
# 4                         70                   36.12500
#
#    day_group_Speed_limit_median  day_group_Speed_limit_sum  \
# 0                          30.0                    7274630
# 1                          30.0                    3643600
# 2                          30.0                    6564900
# 3                          30.0                    6564900
# 4                          30.0                    7274630
#
#    day_group_Speed_limit_diff  day_group_Days_Since_First_Accident_min  \
# 0                   -6.136719                                        0
# 1                   -6.542969                                        0
# 2                    3.953125                                        0
# 3                   -6.046875                                        0
# 4                   -6.136719                                        0
#
#    day_group_Days_Since_First_Accident_max  \
# 0                                      727
# 1                                      723
# 2                                      722
# 3                                      722
# 4                                      727
#
#    day_group_Days_Since_First_Accident_avg  \
# 0                                  177.125
# 1                                  178.375
# 2                                  174.500
# 3                                  174.500
# 4                                  177.125
#
#    day_group_Days_Since_First_Accident_median  \
# 0                                       133.0
# 1                                       133.0
# 2                                       130.0
# 3                                       130.0
# 4                                       133.0
#
#    day_group_Days_Since_First_Accident_sum  \
# 0                                 35660114
# 1                                 17784527
# 2                                 31782574
# 3                                 31782574
# 4                                 35660114
#
#    day_group_Days_Since_First_Accident_diff  accidents_postcode_count  \
# 0                                 161.87500                         7
# 1                                  67.62500                        12
# 2                                  90.50000                        14
# 3                                 -73.50000                        12
# 4                                 -36.15625                        12
#
#    days_postcode_unique  Day_of_Week_unq  Day_of_Week_cnt  \
# 0                     7            56123            95812
# 1                    12            39640            56316
# 2                    14            39640            56316
# 3                    11            35402            48294
# 4                    12            61981           117618
#
#    Local_Authority_(District)_unq  Local_Authority_(District)_cnt  \
# 0                             731                             735
# 1                            1281                            1301
# 2                            1226                            1240
# 3                            5219                            5490
# 4                            1461                            1476
#
#    Local_Authority_(Highway)_unq  Local_Authority_(Highway)_cnt  \
# 0                          15958                          18011
# 1                           2638                           2681
# 2                          25839                          33979
# 3                          12478                          13639
# 4                           8196                           8749
#
#    1st_Road_Class_unq  1st_Road_Class_cnt  Road_Type_unq  Road_Type_cnt  \
# 0               56717               99358          96838         477049
# 1               75385              200278          21679          26969
# 2               77281              209071          26915          34525
# 3               77281              209071          96838         477049
# 4               75385              200278          40291          60872
#
#    2nd_Road_Class_unq  2nd_Road_Class_cnt  \
# 0               84193              255784
# 1               84193              255784
# 2               79320              247729
# 3               79320              247729
# 4               79320              247729
#
#    Pedestrian_Crossing-Human_Control_unq  \
# 0                                  99115
# 1                                  99115
# 2                                  99115
# 3                                  99115
# 4                                  99115
#
#    Pedestrian_Crossing-Human_Control_cnt  \
# 0                                 569874
# 1                                 569874
# 2                                 569874
# 3                                 569874
# 4                                 569874
#
#    Pedestrian_Crossing-Physical_Facilities_unq  \
# 0                                        97337
# 1                                        97337
# 2                                        26848
# 3                                        97337
# 4                                        26848
#
#    Pedestrian_Crossing-Physical_Facilities_cnt  Light_Conditions_unq  \
# 0                                       504070                 95618
# 1                                       504070                 95618
# 2                                        33895                 95618
# 3                                       504070                 95618
# 4                                        33895                 95618
#
#    Light_Conditions_cnt  Weather_Conditions_unq  Weather_Conditions_cnt  \
# 0                464633                   96082                  467111
# 1                464633                   47345                   76431
# 2                464633                   96082                  467111
# 3                464633                   96082                  467111
# 4                464633                   96082                  467111
#
#    Road_Surface_Conditions_unq  Road_Surface_Conditions_cnt  \
# 0                        95216                       448670
# 1                        95216                       448670
# 2                        95216                       448670
# 3                        95216                       448670
# 4                        95216                       448670
#
#    Special_Conditions_at_Site_unq  Special_Conditions_at_Site_cnt  \
# 0                            1556                            1575
# 1                           98170                          535707
# 2                           98170                          535707
# 3                           40458                           57736
# 4                           98170                          535707
#
#    Carriageway_Hazards_unq  Carriageway_Hazards_cnt  Urban_or_Rural_Area_unq  \
# 0                    99200                   576563                    90440
# 1                    99200                   576563                    90440
# 2                    99200                   576563                    90440
# 3                    99200                   576563                    90440
# 4                    99200                   576563                    90440
#
#    Urban_or_Rural_Area_cnt  Did_Police_Officer_Attend_Scene_of_Accident_unq  \
# 0                   380682                                            96709
# 1                   380682                                            59056
# 2                   380682                                            59056
# 3                   380682                                            96709
# 4                   380682                                            59056
#
#    Did_Police_Officer_Attend_Scene_of_Accident_cnt  state_unq  state_cnt  \
# 0                                           492180      98088     523528
# 1                                           107820      98088     523528
# 2                                           107820      98088     523528
# 3                                           492180      98088     523528
# 4                                           107820      98088     523528
#
#    postcode_unq  postcode_cnt  day_group_unq  day_group_cnt  areacode_unq  \
# 0             1             7          77654         201303            15
# 1             1            12          57207          99703             8
# 2             1            14          74898         182123            12
# 3             1            12          74898         182123            14
# 4             1            12          77654         201303            16
#
#    areacode_cnt  tE_Day_of_Week  tE_Local_Authority_(District)  \
# 0            74        1.459961                       1.500000
# 1            29        1.471680                       1.456055
# 2            73        1.469727                       1.410156
# 3            91        1.451172                       1.336914
# 4           117        1.464844                       1.367188
#
#    tE_Local_Authority_(Highway)  tE_1st_Road_Class  tE_Road_Type  \
# 0                      1.486328           1.482422      1.453125
# 1                      1.490234           1.510742      1.486328
# 2                      1.414062           1.407227      1.503906
# 3                      1.439453           1.408203      1.452148
# 4                      1.462891           1.510742      1.507812
#
#    tE_2nd_Road_Class  tE_Pedestrian_Crossing-Human_Control  \
# 0           1.475586                              1.462891
# 1           1.475586                              1.462891
# 2           1.426758                              1.461914
# 3           1.425781                              1.461914
# 4           1.427734                              1.463867
#
#    tE_Pedestrian_Crossing-Physical_Facilities  tE_Light_Conditions  \
# 0                                    1.463867             1.467773
# 1                                    1.463867             1.467773
# 2                                    1.452148             1.466797
# 3                                    1.462891             1.467773
# 4                                    1.456055             1.468750
#
#    tE_Weather_Conditions  tE_Road_Surface_Conditions  \
# 0               1.466797                    1.468750
# 1               1.442383                    1.468750
# 2               1.466797                    1.468750
# 3               1.466797                    1.468750
# 4               1.467773                    1.469727
#
#    tE_Special_Conditions_at_Site  tE_Carriageway_Hazards  \
# 0                       1.523438                1.462891
# 1                       1.463867                1.462891
# 2                       1.462891                1.462891
# 3                       1.458984                1.462891
# 4                       1.463867                1.463867
#
#    tE_Urban_or_Rural_Area  tE_Did_Police_Officer_Attend_Scene_of_Accident  \
# 0                1.436523                                        1.467773
# 1                1.435547                                        1.447266
# 2                1.436523                                        1.445312
# 3                1.436523                                        1.466797
# 4                1.437500                                        1.447266
#
#    tE_state  tE_postcode  tE_day_group  tE_areacode
# 0  1.461914     2.000000      1.468750     1.644531
# 1  1.461914     1.499023      1.462891     1.333008
# 2  1.460938     1.400391      1.461914     1.301758
# 3  1.460938     1.727539      1.461914     1.597656
# 4  1.462891     1.750000      1.469727     1.430664

# %% [markdown]
# # LightGBM

# %%
lgb_best_params = {'colsample_bytree': 0.5265534343795216,
 'learning_rate': 0.03758663589227534,
 'max_depth': 8,
 'metric': 'rmse',
 'min_child_samples': 49,
 'min_data_per_group': 153,
 'n_estimators': 10000,
 'n_jobs': -1,
 'num_leaves': 75,
 'objective': 'regression',
 'random_state': 19920803,
 'reg_alpha': 1.1566640015760366e-07,
 'reg_lambda': 0.06328070355543179,
 'subsample': 0.2965389310542902}

# %%
lgb=LGBMRegressor(**lgb_best_params)
lgb_preds, lgb_scores, lgb_model, lgb_oof = run_clf(lgb, fit_params, train_df_low_mem, test_df_low_mem, features, TARGET_COL, folds=N_FOLDS)
# Out:
# ------------- Fold 1 -------------
# Training until validation scores don't improve for 200 rounds.
# [500]	training's rmse: 0.783412	valid_1's rmse: 0.809796
# Early stopping, best iteration is:
# [544]	training's rmse: 0.781548	valid_1's rmse: 0.809768
#
# RMSE for validation set is 0.80977
#
#
# ------------- Fold 2 -------------
# Training until validation scores don't improve for 200 rounds.
# [500]	training's rmse: 0.784255	valid_1's rmse: 0.801998
# Early stopping, best iteration is:
# [415]	training's rmse: 0.788171	valid_1's rmse: 0.80194
#
# RMSE for validation set is 0.80194
#
#
# ------------- Fold 3 -------------
# Training until validation scores don't improve for 200 rounds.
# [500]	training's rmse: 0.783541	valid_1's rmse: 0.809427
# Early stopping, best iteration is:
# [422]	training's rmse: 0.787157	valid_1's rmse: 0.809351
#
# RMSE for validation set is 0.80935
#
#
# ------------- Fold 4 -------------
# Training until validation scores don't improve for 200 rounds.
# [500]	training's rmse: 0.783702	valid_1's rmse: 0.809299
# Early stopping, best iteration is:
# [779]	training's rmse: 0.771191	valid_1's rmse: 0.809176
#
# RMSE for validation set is 0.80918
#
#
# ------------- Fold 5 -------------
# Training until validation scores don't improve for 200 rounds.
# [500]	training's rmse: 0.782684	valid_1's rmse: 0.814796
# Early stopping, best iteration is:
# [467]	training's rmse: 0.784225	valid_1's rmse: 0.814749
#
# RMSE for validation set is 0.81475
#
#
# ------------- Fold 6 -------------
# Training until validation scores don't improve for 200 rounds.
# [500]	training's rmse: 0.783435	valid_1's rmse: 0.807364
# Early stopping, best iteration is:
# [354]	training's rmse: 0.790409	valid_1's rmse: 0.807156
#
# RMSE for validation set is 0.80716
#
#
# ------------- Fold 7 -------------
# Training until validation scores don't improve for 200 rounds.
# [500]	training's rmse: 0.783458	valid_1's rmse: 0.808303
# Early stopping, best iteration is:
# [436]	training's rmse: 0.786386	valid_1's rmse: 0.808182
#
# RMSE for validation set is 0.80818
#
#
# ------------- Fold 8 -------------
# Training until validation scores don't improve for 200 rounds.
# [500]	training's rmse: 0.784202	valid_1's rmse: 0.803058
# [1000]	training's rmse: 0.762103	valid_1's rmse: 0.802862
# Early stopping, best iteration is:
# [1029]	training's rmse: 0.760877	valid_1's rmse: 0.802824
#
# RMSE for validation set is 0.80282
#
#
# ------------- Fold 9 -------------
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [191]	training's rmse: 0.797805	valid_1's rmse: 0.812349
#
# RMSE for validation set is 0.81235
#
#
# ------------- Fold 10 -------------
# Training until validation scores don't improve for 200 rounds.
# [500]	training's rmse: 0.783073	valid_1's rmse: 0.812729
# [1000]	training's rmse: 0.761338	valid_1's rmse: 0.812546
# Early stopping, best iteration is:
# [968]	training's rmse: 0.762709	valid_1's rmse: 0.812466
#
# RMSE for validation set is 0.81247
#
#
# CV RMSE score: 0.8088
#
# OOF RMSE score: 0.80881

# %%
## Feature importance
show_all(get_feature_importance(lgb_model, train_df_low_mem, features))
# Out:
#                                         Feature  Importance
# 307                                 tE_areacode        1235
# 290               tE_Local_Authority_(District)        1151
# 291                tE_Local_Authority_(Highway)         925
# 305                                 tE_postcode         922
# 212                   postcode_Speed_limit_diff         910
# 288                                areacode_cnt         900
# 9                                      children         801
# 202                postcode_1st_Road_Number_max         799
# 122  Local_Authority_(Highway)_Speed_limit_diff         793
# 14                                  child_ratio         785

# %%
lgb_preds, len(lgb_preds)
# Out:
# (array([1.54482548, 1.38576927, 1.50998743, ..., 1.64020465, 1.26543187,
#         1.23222905]), 121259)

# %% [markdown]
# # XGBOOST

# %%
xgb_best_params = {'colsample_bytree': 0.34651527365396184,
 'eval_metric': 'rmse',
 'learning_rate': 0.014543061344542332,
 'max_depth': 5,
 'n_estimators': 10000,
 'objective': 'reg:squarederror',
 'predictor': 'gpu_predictor',
 'random_state': 19920803,
 'reg_alpha': 27.255858264128506,
 'reg_lambda': 11.554739541654067,
 'subsample': 0.40177414453796234,
 'tree_method': 'gpu_hist',
 'use_label_encoder': False}

# %%
xgb=XGBRegressor(**xgb_best_params)
xgb_preds, xgb_scores, xgb_model, xgb_oof = run_clf(xgb, fit_params, train_df_low_mem, test_df_low_mem, features, TARGET_COL, folds=N_FOLDS)
# Out:
# ------------- Fold 1 -------------
# [0]	validation_0-rmse:1.25159	validation_1-rmse:1.25502
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 200 rounds.
# [500]	validation_0-rmse:0.806502	validation_1-rmse:0.810194
# [1000]	validation_0-rmse:0.804121	validation_1-rmse:0.810025
# [1500]	validation_0-rmse:0.801995	validation_1-rmse:0.809998
# Stopping. Best iteration:
# [1341]	validation_0-rmse:0.802662	validation_1-rmse:0.809985
#
#
# RMSE for validation set is 0.8099899888038635
#
#
# ------------- Fold 2 -------------
# [0]	validation_0-rmse:1.25307	validation_1-rmse:1.24171
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 200 rounds.
# [500]	validation_0-rmse:0.807342	validation_1-rmse:0.802403
# [1000]	validation_0-rmse:0.804984	validation_1-rmse:0.802262
# [1500]	validation_0-rmse:0.802879	validation_1-rmse:0.802207
# Stopping. Best iteration:
# [1480]	validation_0-rmse:0.802959	validation_1-rmse:0.802202
#
#
# RMSE for validation set is 0.8022000193595886
#
#
# ------------- Fold 3 -------------
# [0]	validation_0-rmse:1.2519	validation_1-rmse:1.25237
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 200 rounds.
# [500]	validation_0-rmse:0.806585	validation_1-rmse:0.809703
# [1000]	validation_0-rmse:0.804239	validation_1-rmse:0.80947
# [1500]	validation_0-rmse:0.802109	validation_1-rmse:0.809401
# Stopping. Best iteration:
# [1619]	validation_0-rmse:0.801606	validation_1-rmse:0.80937
#
#
# RMSE for validation set is 0.8093699812889099
#
#
# ------------- Fold 4 -------------
# [0]	validation_0-rmse:1.2521	validation_1-rmse:1.25057
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 200 rounds.
# [500]	validation_0-rmse:0.806598	validation_1-rmse:0.809309
# [1000]	validation_0-rmse:0.804241	validation_1-rmse:0.809135
# [1500]	validation_0-rmse:0.8021	validation_1-rmse:0.809077
# Stopping. Best iteration:
# [1323]	validation_0-rmse:0.802862	validation_1-rmse:0.809064
#
#
# RMSE for validation set is 0.8090599775314331
#
#
# ------------- Fold 5 -------------
# [0]	validation_0-rmse:1.25084	validation_1-rmse:1.26179
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 200 rounds.
# [500]	validation_0-rmse:0.805961	validation_1-rmse:0.815155
# [1000]	validation_0-rmse:0.803588	validation_1-rmse:0.814975
# Stopping. Best iteration:
# [1202]	validation_0-rmse:0.80271	validation_1-rmse:0.814949
#
#
# RMSE for validation set is 0.8149499893188477
#
#
# ------------- Fold 6 -------------
# [0]	validation_0-rmse:1.25217	validation_1-rmse:1.25003
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 200 rounds.
# [500]	validation_0-rmse:0.806827	validation_1-rmse:0.807287
# [1000]	validation_0-rmse:0.804461	validation_1-rmse:0.807095
# Stopping. Best iteration:
# [1128]	validation_0-rmse:0.803906	validation_1-rmse:0.80709
#
#
# RMSE for validation set is 0.8070899844169617
#
#
# ------------- Fold 7 -------------
# [0]	validation_0-rmse:1.25213	validation_1-rmse:1.2502
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 200 rounds.
# [500]	validation_0-rmse:0.806735	validation_1-rmse:0.808325
# [1000]	validation_0-rmse:0.804397	validation_1-rmse:0.808101
# [1500]	validation_0-rmse:0.802271	validation_1-rmse:0.808034
# Stopping. Best iteration:
# [1421]	validation_0-rmse:0.802592	validation_1-rmse:0.808018
#
#
# RMSE for validation set is 0.8080199956893921
#
#
# ------------- Fold 8 -------------
# [0]	validation_0-rmse:1.25275	validation_1-rmse:1.24467
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 200 rounds.
# [500]	validation_0-rmse:0.807275	validation_1-rmse:0.803548
# [1000]	validation_0-rmse:0.804951	validation_1-rmse:0.803307
# Stopping. Best iteration:
# [1246]	validation_0-rmse:0.803872	validation_1-rmse:0.803245
#
#
# RMSE for validation set is 0.8032500147819519
#
#
# ------------- Fold 9 -------------
# [0]	validation_0-rmse:1.25137	validation_1-rmse:1.25713
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 200 rounds.
# [500]	validation_0-rmse:0.806287	validation_1-rmse:0.8125
# [1000]	validation_0-rmse:0.803909	validation_1-rmse:0.812281
# [1500]	validation_0-rmse:0.801791	validation_1-rmse:0.812218
# Stopping. Best iteration:
# [1432]	validation_0-rmse:0.802074	validation_1-rmse:0.812192
#
#
# RMSE for validation set is 0.8121899962425232
#
#
# ------------- Fold 10 -------------
# [0]	validation_0-rmse:1.25151	validation_1-rmse:1.25584
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 200 rounds.
# [500]	validation_0-rmse:0.806182	validation_1-rmse:0.813207
# [1000]	validation_0-rmse:0.803839	validation_1-rmse:0.813038
# [1500]	validation_0-rmse:0.801712	validation_1-rmse:0.812962
# Stopping. Best iteration:
# [1682]	validation_0-rmse:0.800958	validation_1-rmse:0.812949
#
#
# RMSE for validation set is 0.8129500150680542
#
#
# CV RMSE score: 0.8089100122451782
#
# OOF RMSE score: 0.80892

# %%
## Feature Importance
get_feature_importance(xgb_model, train_df_low_mem, features)
# Out:
#                                             Feature  Importance
# 0                                      Police_Force    0.017455
# 81   Local_Authority_(District)_1st_Road_Number_min    0.015405
# 1                                Number_of_Vehicles    0.015240
# 72   Local_Authority_(District)_Police_Force_median    0.013545
# 131                 1st_Road_Class_Police_Force_avg    0.012644
# 34                        Accident_ts_Is_year_start    0.012135
# 137           1st_Road_Class_Number_of_Vehicles_avg    0.012102
# 142              1st_Road_Class_1st_Road_Number_max    0.011961
# 3                                       Speed_limit    0.011519
# 160                      Road_Type_Police_Force_max    0.011260

# %%
xgb_preds, len(xgb_preds)
# Out:
# (array([1.58761175, 1.36721091, 1.54403672, ..., 1.58520295, 1.26018266,
#         1.26013513]), 121259)

# %% [markdown]
# ## Submission

# %%
df_test['preds'] = (0.6 * lgb_preds) + (0.4 * xgb_preds)

# %%
sub_df = df_test.groupby(['postcode']).agg({'preds':'sum', 'Accident_ID':'count'}).reset_index()
sub_df['Accident_risk_index'] = sub_df['preds']/sub_df['Accident_ID']
sub_df
# Out:
#        postcode     preds  Accident_ID  Accident_risk_index
# 0      AB10 1AU  1.339561            1             1.339561
# 1      AB10 1PG  2.751288            2             1.375644
# 2      AB10 1TT  1.529009            1             1.529009
# 3      AB10 1YP  4.335528            3             1.445176
# 4      AB10 6LQ  1.320272            1             1.320272
# ...         ...       ...          ...                  ...
# 49767   ZE2 9LZ  1.333191            1             1.333191
# 49768   ZE2 9RE  5.427805            4             1.356951
# 49769   ZE2 9RJ  1.233127            1             1.233127
# 49770   ZE2 9SB  1.522740            1             1.522740
# 49771   ZE2 9SD  8.035083            6             1.339180
#
# [49772 rows x 4 columns]

# %%
FILE_TIMESTAMP = datetime.now().strftime('%m%d%Y_%H%M')
MODEL_NAME = 'LGB_XGB'
OUTPUT_FILE_NAME = f"sub_{MODEL_NAME}_{FILE_TIMESTAMP}.csv"

# %%
final_sub = sub_df[['postcode', 'Accident_risk_index']]
final_sub
# Out:
#        postcode  Accident_risk_index
# 0      AB10 1AU             1.339561
# 1      AB10 1PG             1.375644
# 2      AB10 1TT             1.529009
# 3      AB10 1YP             1.445176
# 4      AB10 6LQ             1.320272
# ...         ...                  ...
# 49767   ZE2 9LZ             1.333191
# 49768   ZE2 9RE             1.356951
# 49769   ZE2 9RJ             1.233127
# 49770   ZE2 9SB             1.522740
# 49771   ZE2 9SD             1.339180
#
# [49772 rows x 2 columns]

# %%
final_sub.to_csv(OUTPUT_FILE_NAME, index=False)
